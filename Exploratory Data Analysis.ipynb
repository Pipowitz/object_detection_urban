# %% [markdown]
# # Explore the dataset
#
#
# In this notebook, we will perform an EDA (Exploratory Data Analysis) on the processed Waymo dataset (data in the `processed` folder). In the first part, you will create a function to display

# %%
from utils import get_dataset
import glob
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import tensorflow as tf
import numpy as np
from matplotlib.patches import Rectangle
from collections import Counter

# %matplotlib inline

# %%
dataset = get_dataset("/home/workspace/data/train/*.tfrecord")
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['/home/workspace/data/train/*.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/workspace/data/train/*.tfrecord']
# INFO:tensorflow:Number of filenames to read: 86
# WARNING:tensorflow:From /data/virtual_envs/sdc-c1-gpu-augment/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# ...

# %% [markdown]
# ## Write a function to display an image and the bounding boxes
#
# Implement the `display_images` function below. This function takes a batch as an input and display an image with its corresponding bounding boxes. The only requirement is that the classes should be color coded (eg, vehicles in red, pedestrians in blue, cyclist in green).

# %%
def display_images(batch):
    '''
    displays an image along with the bounding boxes of the objects found in said image.
    The bounding boxes are color coded by the class of the objects.
    
    inputs:
        -batch: a dict containing all relevant image information
    '''
    
    # the color maping of the classes
    colormap={1: [1, 0, 0], 2: [0, 1, 0],4: [0, 0, 1]}
    
    # extract the relevant information for the image
    bboxes=batch['groundtruth_boxes']
    classes=batch['groundtruth_classes'].numpy()
    img=batch['image']
    size=img.shape
    
    fig, ax = plt.subplots(1, 1)
    
    # build the bounding boxes, color code them and put them into
    # the image
    for cl, bb in zip(classes, bboxes):
        plt.imshow(img)
        y1, x1, y2, x2 = bb
        
        # seems like they need to be turned into absolute values, 
        # as the bboxes coordinates are relative
        y1 = y1*size[0]
        x1 = x1*size[1]
        y2 = y2*size[0]
        x2 = x2*size[1]
        
        rec = Rectangle((x1, y1), x2-x1, y2-y1, facecolor='none',
                       edgecolor=colormap[cl])

        ax.add_patch(rec)
        
    ax.axis('off')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Display 10 images
#
# Using the dataset created in the second cell and the function you just coded, display 10 random images with the associated bounding boxes. You can use the methods `take` and `shuffle` on the dataset.

# %%
# Display 10 random images in dataset
for batch in dataset.shuffle(99).take(10):
    display_images(batch)

# %% [markdown]
# ## Additional EDA
#
# In this last part, you are free to perform any additional analysis of the dataset. What else would like to know about the data?
# For example, think about data distribution. So far, you have only looked at a single file...

# %%
#iterate through the dataset
#concate all class arrays and make a list of the number of objects per picture
class_array=np.array([])
obj_num_per_pic=[]
for picture in dataset.take(50000):
    class_array=np.concatenate((class_array, picture['groundtruth_classes'].numpy()))
    obj_num_per_pic.append(len(picture['groundtruth_classes'].numpy()))

# %%
#get the unique object classes and their count
unique, counts=np.unique(class_array, return_counts=True)

# %%
counts
# Out:
# array([864332, 243166,   6213])

# %%
#plot the occurance of classes
plt.title("Counts per class")
plt.xlabel("Types")
plt.ylabel("Counts")
plt.bar(unique, counts)
# Out:
# <BarContainer object of 3 artists>

# %%
#transform the list
obj_num_dict=Counter(obj_num_per_pic)

# %%
#plot the occurance objects per picture
plt.title("Objects per picture")
plt.xlabel("Number of pictures")
plt.ylabel("Number of objects in picture")
plt.bar(obj_num_dict.keys(), obj_num_dict.values())
# Out:
# <BarContainer object of 76 artists>
